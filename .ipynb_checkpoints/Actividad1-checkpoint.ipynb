# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2 as cv

# %%
def loadImage(url):
    return cv.imread(url, cv.IMREAD_GRAYSCALE)

img = loadImage('./Image.png')
plt.imshow(img)

# %%
# Out:
# [[34 34 28 ... 28 28 28]
#  [34 34 28 ... 28 28 21]
#  [34 34 28 ... 28 28 21]
#  ...
#  [78 70 61 ... 21 21 21]
#  [78 68 61 ... 21 21 21]
#  [80 70 61 ... 21 21 21]]
